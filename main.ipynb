# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

glob_temp = pd.read_csv("annual.csv")

glob_temp = glob_temp[glob_temp["Source"] == "GISTEMP"] 
glob_temp.head(n=50)

# Global temperature increase graph
plt.figure(figsize=(12,6))
plt.title("Global temperature increase")
sns.lineplot(x=glob_temp["Year"] ,y=glob_temp["Mean"])

crops_df = pd.read_csv("Sorted_crops.csv")
crops_df.head()
crops_df = crops_df.fillna(method="bfill")
print(crops_df["Entity"].nunique())
print(crops_df["Entity"].unique())

crops_bih = crops_df[crops_df["Entity"] == "Bosnia and Herzegovina"].reset_index()

plt.figure(figsize=(12,6))
sns.lineplot(y=crops_df["rice_yield_gap"], x=crops_df["Year"])

crops_df = crops_df[crops_df["Entity"] == "Nigeria"].reset_index()
crops_df["avg_rice_yield"] = crops_df["rice_attainable"] - crops_df["rice_yield_gap"]
crops_df = crops_df[["Entity", "Year", "rice_yield_gap", "avg_rice_yield"]]
crops_df.head()

sns.lineplot(y=crops_df["avg_rice_yield"], x=crops_df["Year"])
plt.legend(labels=["Gloabal rice yield gap", "", "Average farmer rice yield in Nigeria"])
# Out:
# 154
# ['Afghanistan' 'Peru' 'Paraguay' 'Papua New Guinea' 'Panama' 'Pakistan'
#  'Oman' 'Norway' 'Nigeria' 'Niger' 'Nicaragua' 'New Zealand' 'Austria'
#  'New Caledonia' 'Bangladesh' 'Nepal' 'Namibia' 'Myanmar' 'Mozambique'
#  'Morocco' 'Barbados' 'Mexico' 'Mauritius' 'Malta' 'Mali' 'Netherlands'
#  'Philippines' 'Poland' 'Portugal' 'Tunisia' 'Trinidad and Tobago' 'Tonga'
#  'Togo' 'Thailand' 'Angola' 'Tanzania' 'Syria' 'Switzerland' 'Sweden'
#  'Suriname' 'Sri Lanka' 'Argentina' 'Spain' 'South Korea' 'South Africa'
#  'Singapore' 'Seychelles' 'Senegal' 'Saudi Arabia' 'Samoa' 'Australia'
#  'Saint Kitts and Nevis' 'Rwanda' 'Romania' 'Maldives' 'Algeria'
#  'Malaysia' 'Madagascar' 'Brazil' 'French Polynesia' 'France' 'Finland'
#  'El Salvador' 'Egypt' 'Ecuador' 'Brunei' 'Dominica' 'Denmark'
#  'Democratic Republic of Congo' 'Gabon' 'Cyprus' "Cote d'Ivoire"
#  'Bulgaria' 'Costa Rica' 'Congo' 'Colombia' 'China' 'Chile' 'Burkina Faso'
#  'Canada' 'Cameroon' 'Cambodia' 'Cuba' 'Gambia' 'Germany' 'Ghana' 'Belize'
#  'Libya' 'Lebanon' 'Kenya' 'Jordan' 'Japan' 'Jamaica' 'Benin' 'Italy'
#  'Israel' 'Ireland' 'Iraq' 'Iran' 'Bhutan' 'Indonesia' 'India' 'Iceland'
#  'Hungary' 'Honduras' 'Guyana' 'Bolivia' 'Guinea' 'Guatemala' 'Grenada'
#  'Greece' 'Malawi' 'Turkey' 'Mongolia' 'Burundi' 'World' 'Zambia' 'Uganda'
#  'Vietnam' 'United Kingdom' 'Albania' 'Zimbabwe' 'Venezuela' 'Uruguay'
#  'Yemen' 'United States' 'Kuwait' 'Qatar' 'United Arab Emirates' 'Bahrain'
#  'Russia' 'North Macedonia' 'Belarus' 'Lithuania' 'Moldova' 'Tajikistan'
#  'Bosnia and Herzegovina' 'Georgia' 'Kazakhstan' 'Slovenia' 'Croatia'
#  'Estonia' 'Ukraine' 'Azerbaijan' 'Latvia' 'Serbia and Montenegro'
#  'Armenia' 'Kyrgyzstan' 'Ethiopia' 'Eritrea' 'Slovakia' 'Czechia'
#  'Luxembourg' 'Sudan']

# %%
plt.figure(figsize=(12,6))
plt.title("Rice production in Nigeria and global mean temperature")
sns.lineplot(x=glob_temp["Year"], y=glob_temp["Mean"])
plt.ylabel("Mean")

# plot rice production in Nigeria
sns.lineplot(x=crops_df["Year"], y=crops_df["avg_rice_yield"])
# Out:
# <AxesSubplot:title={'center':'Rice production in Nigeria and global mean temperature'}, xlabel='Year', ylabel='Mean'>

# %%
print(crops_bih.head())
plt.figure(figsize=(12,6))
plt.title("BiH crops")
# Out:
#    index                  Entity  Year  barley_attainable  cassava_attainable  \
# 0   4049  Bosnia and Herzegovina  1992               6.26                 0.0
# 1   4149  Bosnia and Herzegovina  1993               6.26                 0.0
# 2   4400  Bosnia and Herzegovina  1994               6.26                 0.0
# 3   4558  Bosnia and Herzegovina  1995               6.26                 0.0
# 4   4614  Bosnia and Herzegovina  1996               6.26                 0.0
#
#    cotton_attainable  groundnut_attainable  maize_attainable  \
# 0                0.0                   0.0               9.7
# 1                0.0                   0.0               9.7
# 2                0.0                   0.0               9.7
# 3                0.0                   0.0               9.7
# 4                0.0                   0.0               9.7
#
#    millet_attainable  oilpalm_attainable  ...  soybeans_yield_gap  \
# 0                0.0                 0.0  ...                1.04
# 1                0.0                 0.0  ...                1.30
# 2                0.0                 0.0  ...                1.75
# 3                0.0                 0.0  ...                1.38
# 4                0.0                 0.0  ...                1.68
#
#    rapeseed_yield_gap  sugarbeet_yield_gap  sugarcane_yield_gap  \
# 0                0.84                21.51                62.63
# 1                1.94                26.12                 0.00
# 2                1.26                31.43                43.65
# 3                1.26                39.40                 1.28
# 4                1.92                44.40                28.38
#
#    potato_yield_gap  oilpalm_yield_gap  groundnut_yield_gap  rice_yield_gap  \
# 0             34.15               8.10                 4.36            5.35
# 1             33.64               5.99                 1.46            4.34
# 2             35.14               4.60                 0.00            7.05
# 3             35.03               2.12                 0.73            0.78
# 4             33.70               5.46                 0.98            4.95
#
#    sunflower_yield_gap  cotton_yield_gap
# 0                 1.90               0.0
# 1                 1.92               0.0
# 2                 1.95               0.0
# 3                 1.89               0.0
# 4                 1.88               0.0
#
# [5 rows x 37 columns]
# Text(0.5, 1.0, 'BiH crops')
